# %% [markdown]
# <a href="https://colab.research.google.com/github/SabanaSultana/Python_AI/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Variable, Data Types, Operators, Control Flow(IF, Else & Loops)

# %%
print("Line 1")
# Out:
# Line 1

# %%
a, b, c=10,23,34
print(a)
# Out:
# 10

# %%
print(b)
# Out:
# 23

# %%
print(type("Sabana"))
# Out:
# <class 'str'>

# %%
print(type(11))
# Out:
# <class 'int'>

# %%
a="10"
print(float(a))
# Out:
# 10.0

# %%
print(10==20)
# Out:
# False

# %%
print(10=='10')
# Out:
# False

# %%
if a==10 and b==30:
   print(a,b, sep="....")
else:
   print("Data doesn't match")
# Out:
# Data doesn't match

# %%
print(10|20)
# Out:
# 30

# %%
# print('Sabana' + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2578723875.py in <cell line: 0>()
# ----> 1 print('Sabana' +5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("sabana", 5)
# Out:
# sabana 5

# %%
# print(5 +'10')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3377659249.py in <cell line: 0>()
# ----> 1 print(5 +'10')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print('sabana' + '10')
# Out:
# sabana10

# %%
print(10 + int('10'))
# Out:
# 20

# %%
print(10*20)
# Out:
# 200

# %%
print(10**2)
# Out:
# 100

# %%
print(10/2)
# Out:
# 5.0

# %%
print(10//2)
# Out:
# 5

# %%
print(11/2)
# Out:
# 5.5

# %%
print(11//2)
# Out:
# 5

# %%
print(12%3)
# Out:
# 0

# %%
print(11%3)
# Out:
# 2

# %%
print('10'=='sabana')
# Out:
# False

# %%
print(10=='10')
# Out:
# False

# %%
print('Sabana'=="Sabana")
# Out:
# True

# %%
print('Sabana'=='sabana')
# Out:
# False
